# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/credit_card_pw_hindi/main/creditCardFraud_28011964_120214.csv")

# %%
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      50000    1          2         1   57     -1      0     -1      0
# 1      50000    1          1         2   37      0      0      0      0
# 2     500000    1          1         2   29      0      0      0      0
# 3     100000    2          2         2   23      0     -1     -1      0
# 4     140000    2          3         1   28      0      0      2      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0      0  ...      20940      19146      19131      2000     36681     10000
# 1      0  ...      19394      19619      20024      2500      1815       657
# 2      0  ...     542653     483003     473944     55000     40000     38000
# 3      0  ...        221       -159        567       380       601         0
# 4      0  ...      12211      11793       3719      3329         0       432
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df.shape
# Out:
# (1001, 24)

# %%
df['default payment next month'].unique()
# Out:
# array([0, 1])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   LIMIT_BAL                   1001 non-null   int64
#  1   SEX                         1001 non-null   int64
#  2   EDUCATION                   1001 non-null   int64
#  3   MARRIAGE                    1001 non-null   int64
#  4   AGE                         1001 non-null   int64
#  5   PAY_0                       1001 non-null   int64
#  6   PAY_2                       1001 non-null   int64
#  7   PAY_3                       1001 non-null   int64
#  8   PAY_4                       1001 non-null   int64
#  9   PAY_5                       1001 non-null   int64
#  10  PAY_6                       1001 non-null   int64
#  11  BILL_AMT1                   1001 non-null   int64
#  12  BILL_AMT2                   1001 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
x = df.drop('default payment next month',axis=1)

# %%
y = df['default payment next month']

# %%
x
# Out:
#       LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0         50000    1          2         1   57     -1      0     -1      0
# 1         50000    1          1         2   37      0      0      0      0
# 2        500000    1          1         2   29      0      0      0      0
# 3        100000    2          2         2   23      0     -1     -1      0
# 4        140000    2          3         1   28      0      0      2      0
# ...         ...  ...        ...       ...  ...    ...    ...    ...    ...
# 996      100000    1          2         1   29      0      0      0      0
# 997      200000    2          2         1   28      0      0      0      0
# 998       90000    2          2         1   40     -1     -1     -1     -1
# 999      360000    1          1         2   36      1     -2     -2     -2
# 1000     150000    2          3         2   30     -2     -2     -2     -2
#
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 996     0
# 997     0
# 998     0
# 999     1
# 1000    1
# Name: default payment next month, Length: 1001, dtype: int64

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=69)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train.max()
# Out:
# np.float64(19.962575988354352)

# %%
x_train.min()
# Out:
# np.float64(-6.011583587684485)

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()

# %%
nb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_predicted = nb.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
print(accuracy_score(y_test,y_predicted)*100)
print(confusion_matrix(y_test,y_predicted))
print(classification_report(y_test,y_predicted))
# Out:
# 71.64179104477611
# [[121  35]
#  [ 22  23]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.78      0.81       156
#            1       0.40      0.51      0.45        45
#
#     accuracy                           0.72       201
#    macro avg       0.62      0.64      0.63       201
# weighted avg       0.75      0.72      0.73       201

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.naive_bayes import GaussianNB
new_nb = GaussianNB()

# %%
grid = {'var_smoothing' : [1e-9,0.1, 0.001, 0.5,0.05,0.01,1e-8,1e-7,1e-6,1e-10,1e-11]}

# %%
gs = GridSearchCV(new_nb,param_grid=grid,cv=5,verbose=3)

# %%
gs.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 11 candidates, totalling 55 fits
# [CV 1/5] END ...............var_smoothing=1e-09;, score=0.738 total time=   0.0s
# [CV 2/5] END ...............var_smoothing=1e-09;, score=0.750 total time=   0.0s
# [CV 3/5] END ...............var_smoothing=1e-09;, score=0.406 total time=   0.0s
# [CV 4/5] END ...............var_smoothing=1e-09;, score=0.713 total time=   0.0s
# [CV 5/5] END ...............var_smoothing=1e-09;, score=0.688 total time=   0.0s
# [CV 1/5] END .................var_smoothing=0.1;, score=0.750 total time=   0.0s
# [CV 2/5] END .................var_smoothing=0.1;, score=0.750 total time=   0.0s
# [CV 3/5] END .................var_smoothing=0.1;, score=0.469 total time=   0.0s
# [CV 4/5] END .................var_smoothing=0.1;, score=0.744 total time=   0.0s
# [CV 5/5] END .................var_smoothing=0.1;, score=0.706 total time=   0.0s
# [CV 1/5] END ...............var_smoothing=0.001;, score=0.738 total time=   0.0s
# ...

# %%
gs.best_params_
# Out:
# {'var_smoothing': 0.5}

# %%
y_predicted_new = gs.predict(x_test)

# %%
print(accuracy_score(y_test,y_predicted_new)*100)
print(confusion_matrix(y_test,y_predicted_new))
print(classification_report(y_test,y_predicted_new))
# Out:
# 77.61194029850746
# [[137  19]
#  [ 26  19]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86       156
#            1       0.50      0.42      0.46        45
#
#     accuracy                           0.78       201
#    macro avg       0.67      0.65      0.66       201
# weighted avg       0.76      0.78      0.77       201

# %%
from sklearn.svm import SVC
svc = SVC()

# %%
grid = {'C':[0.1,0.5,1,10,100],
        'kernel':['linear', 'poly', 'rbf', 'sigmoid'],
        'gamma':['scale','auto']}

# %%
svc_gs = GridSearchCV(svc,param_grid=grid,verbose=3)

# %%
svc_gs.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV 1/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.794 total time=   0.0s
# [CV 2/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.787 total time=   0.0s
# [CV 3/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.787 total time=   0.0s
# [CV 4/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.787 total time=   0.0s
# [CV 5/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.787 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=scale, kernel=poly;, score=0.794 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=scale, kernel=poly;, score=0.794 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=scale, kernel=poly;, score=0.794 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=scale, kernel=poly;, score=0.781 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=scale, kernel=poly;, score=0.800 total time=   0.0s
# [CV 1/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.794 total time=   0.0s
# ...

# %%
svc_gs.best_params_
# Out:
# {'C': 0.1, 'gamma': 'auto', 'kernel': 'poly'}

# %%
y_predicted_svc = svc_gs.predict(x_test)

# %%
print(accuracy_score(y_test,y_predicted_svc)*100)
print(confusion_matrix(y_test,y_predicted_svc))
print(classification_report(y_test,y_predicted_svc))
# Out:
# 76.61691542288557
# [[153   3]
#  [ 44   1]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.98      0.87       156
#            1       0.25      0.02      0.04        45
#
#     accuracy                           0.77       201
#    macro avg       0.51      0.50      0.45       201
# weighted avg       0.66      0.77      0.68       201

# %%
from sklearn.naive_bayes import GaussianNB
opt_NB = GaussianNB(var_smoothing = 0.5)
opt_NB.fit(x_train,y_train)
y_predicted_optNB = opt_NB.predict(x_test)

# %%
print(accuracy_score(y_test,y_predicted_optNB)*100)
print(confusion_matrix(y_test,y_predicted_optNB))
print(classification_report(y_test,y_predicted_optNB))
# Out:
# 77.61194029850746
# [[137  19]
#  [ 26  19]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86       156
#            1       0.50      0.42      0.46        45
#
#     accuracy                           0.78       201
#    macro avg       0.67      0.65      0.66       201
# weighted avg       0.76      0.78      0.77       201

# %%
import pickle
file = open('STD_Scaler.pkl','wb')
pickle.dump(scaler,file)
file.close()

# %%
file = open('GaussianNB.pkl','wb')
pickle.dump(opt_NB,file)
file.close()
